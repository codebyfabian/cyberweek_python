# %% [markdown]
# ## Übungsaufgaben zu Listen und Tupel in Python
# Im Folgenden werden 10 Aufgaben zu Listen und Tupel vorgestellt, um das Erzeugen, Suchen und Ersetzen von Elementen zu üben.

# %% [markdown]
# ### Aufgabe 1: Erstelle eine Liste
# Erstelle eine Liste namens `my_list` mit den Zahlen 1, 2, 3, 4 und 5.

# %%
# Ihre Loesung
my_list = [1, 2, 3,4,5]
print(my_list)
# Out:
# [1, 2, 3, 4, 5]

# %% [markdown]
# ### Musterlösung
# Bitte erst öffnen, wenn Sie eine eigene Lösung haben.

# %%
# Musterloesung
# Solution:
my_list = [1, 2, 3, 4, 5]
print(my_list)

# %% [markdown]
# ### Aufgabe 2: Zugriff auf Listenelemente
# Gib das dritte Element aus der Liste `my_list` aus.

# %%
# Ihre Loesung
print(my_list[2])
# Out:
# 3

# %% [markdown]
# ### Musterlösung
# Bitte erst öffnen, wenn Sie eine eigene Lösung haben.

# %%
# Musterloesung
# Solution:
print(my_list[2]) # Index starts at 0
# Out:
# 3

# %% [markdown]
# ### Aufgabe 3: Ändern von Listenelementen
# Ändere das zweite Element der Liste `my_list` zu 10.

# %%
# Ihre Loesung
my_list[1] = 10
print(my_list)
# Out:
# [1, 10, 3, 4, 5]

# %% [markdown]
# ### Musterlösung
# Bitte erst öffnen, wenn Sie eine eigene Lösung haben.

# %%
# Musterloesung
# Solution:
my_list[1] = 10
print(my_list)

# %% [markdown]
# ### Aufgabe 4: Hinzufügen von Elementen zu einer Liste
# Füge die Zahl 6 am Ende der Liste `my_list` hinzu.

# %%
# Ihre Loesung
my_list.append(6)
print(my_list)
# Out:
# [1, 10, 3, 4, 5, 6]

# %% [markdown]
# ### Musterlösung
# Bitte erst öffnen, wenn Sie eine eigene Lösung haben.

# %%
# Musterloesung
# Solution:
my_list.append(6)
print(my_list)

# %% [markdown]
# ### Aufgabe 5: Erstelle ein Tupel
# Erstelle ein Tupel namens `my_tuple` mit den Werten 'a', 'b', und 'c'.

# %%
# Ihre Loesung
my_tupel = ('a', 'b', 'c')
print(my_tupel)
# Out:
# ('a', 'b', 'c')

# %% [markdown]
# ### Musterlösung
# Bitte erst öffnen, wenn Sie eine eigene Lösung haben.

# %%
# Musterloesung
# Solution:
my_tuple = ('a', 'b', 'c')
print(my_tuple)

# %% [markdown]
# ### Aufgabe 6: Zugriff auf Tuple-Elemente
# Gib das zweite Element des Tupels `my_tuple` aus.

# %%
# Ihre Loesung
print(f'{my_tuple[1]} ')
# Out:
# b

# %% [markdown]
# ### Musterlösung
# Bitte erst öffnen, wenn Sie eine eigene Lösung haben.

# %%
# Musterloesung
# Solution:
print(my_tuple[1]) # Index starts at 0

# %% [markdown]
# ### Aufgabe 7: Suchen in einer Liste
# Prüfe, ob die Zahl 3 in der Liste `my_list` vorhanden ist und gib das Ergebnis aus.

# %%
# Ihre Loesung
print(3 in my_list)
# Out:
# True

# %% [markdown]
# ### Musterlösung
# Bitte erst öffnen, wenn Sie eine eigene Lösung haben.

# %%
# Musterloesung
# Solution:
print(3 in my_list)

# %% [markdown]
# ### Aufgabe 8: Länge einer Liste
# Gib die Länge der Liste `my_list` aus.

# %%
# Ihre Loesung
print(len(my_list))
# Out:
# 6

# %% [markdown]
# ### Musterlösung
# Bitte erst öffnen, wenn Sie eine eigene Lösung haben.

# %%
# Musterloesung
# Solution:
print(len(my_list))

# %% [markdown]
# ### Aufgabe 9:  Ersetze mehrere Elemente in einer Liste
# Ersetze die ersten drei Elemente der Liste `my_list` durch die Zahlen 11, 12 und 13. Gib die Liste aus.

# %%
# Ihre Loesung
my_list[0:3] = [11,12,13]
print(my_list)
# Out:
# [11, 12, 13, 4, 5, 6]

# %% [markdown]
# ### Musterlösung
# Bitte erst öffnen, wenn Sie eine eigene Lösung haben.

# %%
# Musterloesung
# Solution:
my_list[0:3] = [11, 12, 13]
print(my_list)

# %% [markdown]
# ### Aufgabe 10:  Konvertierung zwischen Liste und Tupel
# Konvertiere die Liste `my_list` in ein Tupel und weise es der Variable `my_new_tuple` zu. Gib den Typ von `my_new_tuple` aus.

# %%
# Ihre Loesung
new_my_tuple = tuple(my_list)
print(new_my_tuple)
print(type(my_list))
print (type(new_my_tuple))
for index,value in enumerate(my_list):
     print(f'{index} -> {value}')
# Out:
# (11, 12, 13, 4, 5, 6)
# <class 'list'>
# <class 'tuple'>
# 0 -> 11
# 1 -> 12
# 2 -> 13
# 3 -> 4
# 4 -> 5
# 5 -> 6

# %% [markdown]
# ### Musterlösung
# Bitte erst öffnen, wenn Sie eine eigene Lösung haben.

# %%
# Musterloesung
# Solution:
my_new_tuple = tuple(my_list)
print(type(my_new_tuple))

# %% [markdown]
# ### Info
# Dieses Jupyter-Notebook wurde am 28.01.2025 um 15:49:26 mit dem Large-Language-Model gemini-2.0-flash-exp erzeugt.
# Der Prompt lautete: "Erzeuge 10 einfache Python-Übungsaufgaben samt Lösungen zu Listen und Tupel. Dabei sollen insbesondere Erzeugen, Suchen und Ersetzen von Elementen geübt werden."

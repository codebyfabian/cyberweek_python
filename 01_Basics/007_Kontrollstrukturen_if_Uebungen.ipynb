# %% [markdown]
# # Übungen zu Verzweigungen in Python
# In diesem Notebook finden Sie 5 Übungsaufgaben mit Lösungen, die sich mit Verzweigungen in Python beschäftigen.
#
# Sehen Sie sich für die Übung zunächst die Notebooks __[Ein-und Ausgabe](./008_Print_Input.ipynb)__ und __[Formatierte Ausgabe](./009_Formated_Print.ipynb)__ an.
#
# Weiterhin benötigen Sie __[Typ-Umwandlungen](http://localhost:8888/lab/tree/Python_2025/01_Basics/002_TypeCast.ipynb)__, weil die `input`-Funktion eine Zeichenkette zurückgibt, und diese ggfs. in eine Zahl umgewandelt werden soll.

# %% [markdown]
# ## Übung 1
# Schreiben Sie ein Programm, das eine Zahl vom Benutzer einliest und überprüft, ob die Zahl positiv, negativ oder null ist. Geben Sie eine entsprechende Nachricht aus.

# %%
value = input("Please enter a number: ")
if value == 0:
    print("Value is zero.")
elif value < str(0):
    print("Value is negative.")
else:
    print("Value is positive.")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 value = input("Please enter a number: ")
#       2 if value == 0:
#       3     print("Value is zero.")
#
# File /Library/Python/3.9/site-packages/ipykernel/kernelbase.py:1282, in Kernel.raw_input(self, prompt)
#    1280     msg = "raw_input was called, but this frontend does not support input requests."
#    1281     raise StdinNotImplementedError(msg)
# -> 1282 return self._input_request(
#    1283     str(prompt),
#    1284     self._parent_ident["shell"],
#    1285     self.get_parent("shell"),
#    1286     password=False,
#    1287 )
#
# File /Library/Python/3.9/site-packages/ipykernel/kernelbase.py:1325, in Kernel._input_request(self, prompt, ident, parent, password)
#    1322 except KeyboardInterrupt:
#    1323     # re-raise KeyboardInterrupt, to truncate traceback
#    1324     msg = "Interrupted by user"
# -> 1325     raise KeyboardInterrupt(msg) from None
#    1326 except Exception:
#    1327     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %% [markdown]
# ## Übung 2
# Schreiben Sie ein Programm, das eine Note (zwischen 1 und 5) vom Benutzer einliest und die entsprechende Bewertung ausgibt (1: Sehr gut, 2: Gut, 3: Befriedigend, 4: Ausreichend, 5: Mangelhaft).

# %%
# %%sql

# %%
note = input("Please enter a mark between 1 and 5: ")
list = ["1: Sehr gut", "2: Gut", "3: Befriedigend", "4: Ausreichend","5: Mangelhaft"]
print(list[int(note)-1])
# Out:
# 4: Ausreichend

# %% [markdown]
# ## Übung 3
# Schreiben Sie ein Programm, das das Alter einer Person einliest und überprüft, ob die Person ein Kind (0-12 Jahre), ein Teenager (13-19 Jahre), ein Erwachsener (20-64 Jahre) oder ein Senior (65 Jahre und älter) ist.

# %%
alter = input("Bitte geben Sie das Alter einer Person ein: ")
if int(alter) < 13:
    print("Kind")
elif int(alter) >= 13 and int(alter) < 20:
    print("Teenager")
elif int(alter) >= 64:
    print("Senior")
# Out:
# Kind

# %% [markdown]
# ## Übung 4
# Schreiben Sie ein Programm, das eine Zahl vom Benutzer einliest und überprüft, ob die Zahl gerade oder ungerade ist.

# %%
zahl = input("Please enter a number: ")
if int(zahl) % 2 == 0:
    print("Zahl ist gerade")
else:
    print("Zahl ist ungerade")
# Out:
# Zahl ist ungerade

# %% [markdown]
# ## Übung 5
# Schreiben Sie ein Programm, das eine Temperatur in Grad Celsius vom Benutzer einliest und überprüft, ob es kalt (unter 10 Grad), warm (zwischen 10 und 25 Grad) oder heiß (über 25 Grad) ist.

# %%
temperatur = input("Bitte geben Sie eine Temperatur ein: ")
temperatur=int(temperatur)
if temperatur < 10:
    print("kalt")
elif temperatur <= 25:
    print("warm")
elif temperatur > 25:
    print("heiß")
# Out:
# kalt

# %% [markdown]
# Zurück zu __[Kontrollstrukturen](./006_Kontrollstrukturen.ipynb)__
#
# Weiter zu __[Lösungen](./007_Kontrollstrukturen_if_Uebungen_Loesungen.ipynb)__
#
# [Übersicht](./000_Uebersicht.ipynb)

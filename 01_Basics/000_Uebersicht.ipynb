# %% [markdown]
# # Einführung in die Programmierung mit Python
#
# ## Übersicht
#
# [001_Intro](./001_Intro.ipynb)
#
# [002_Datentypen](./002_Datentypen.ipynb)
#
# [002_TypeCast](./002_TypeCast.ipynb)
#
# [003_Variablen](./003_Variablen.ipynb)
#
# [004_Variablen_II](./004_Variablen_II.ipynb)
#
# [005b_Variablen_Uebungen_Loesungen](./005b_Variablen_Uebungen_Loesungen.ipynb)
#
# [005_Variablen_Uebungen](./005_Variablen_Uebungen.ipynb)
#
# [006_Kontrollstrukturen](./006_Kontrollstrukturen.ipynb)
#
# [007_Kontrollstrukturen_if_Uebungen](./007_Kontrollstrukturen_if_Uebungen.ipynb)
#
# [007b_Kontrollstrukturen_if_Uebungen_Loesungen](./007b_Kontrollstrukturen_if_Uebungen_Loesungen.ipynb)
#
# [008_Print_Input](./008_Print_Input.ipynb)
#
# [009_Formated_Print](./009_Formated_Print.ipynb)
#
# [010_For_List_Uebungen](./010_For_List_Uebungen.ipynb)
#
# [010_For_List_Uebungen_Loesungen](./010b_For_List_Uebungen_Loesungen.ipynb)
#
# [011_For_Range_Uebungen](./011_For_Range_Uebungen.ipynb)
#
# [011b_For_Range_Uebungen_Loesungen](./011_For_Range_Uebungen_Loesungen.ipynb)
#
# [012_While_Uebungen](./012_While_Uebungen.ipynb)
#
# [012_While_Uebungen_Loesungen](./012_While_Uebungen_Loesungen.ipynb)

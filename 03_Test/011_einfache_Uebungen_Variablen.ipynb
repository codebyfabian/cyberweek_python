# %% [markdown]
# # Übungen: Variablen, Datentypen und Typumwandlung\n\nDieses Notebook enthält 5 einfache Übungen zu Python-Variablen. Der Fokus liegt auf der Bestimmung von Datentypen und der Umwandlung (Casting) zwischen diesen.

# %% [markdown]
# ### Aufgabe 1: Datentypen erkennen\nErstelle drei Variablen:\n1. Eine Variable `name` mit einem beliebigen Namen (String).\n2. Eine Variable `alter` mit einer Ganzzahl (Integer).\n,3. Eine Variable `gewicht` mit einer Kommazahl (Float).\n\nNutze anschließend die Funktion `type()`, um die Datentypen dieser drei Variablen auszugeben.

# %%
# Ihre Loesung

# %% [markdown]
# ### Musterlösung
# Bitte erst öffnen, wenn Sie eine eigene Lösung haben.

# %%
# Musterloesung
# Dein Code hier\n

# %% [markdown]
# #### Lösung zu Aufgabe 1:

# %%
# Ihre Loesung

# %% [markdown]
# ### Musterlösung
# Bitte erst öffnen, wenn Sie eine eigene Lösung haben.

# %%
# Musterloesung
name = "Max"\n,

# %% [markdown]
# ### Aufgabe 2: String zu Integer umwandeln\nGegeben ist die Variable `zahl_als_text = "50"`. \nVersuche, diese Variable mit der Zahl `20` zu addieren. Du musst `zahl_als_text` vorher in eine Ganzzahl umwandeln, damit kein Fehler auftritt. Speichere das Ergebnis in der Variable `summe` und gib es aus.

# %%
# Ihre Loesung

# %% [markdown]
# ### Musterlösung
# Bitte erst öffnen, wenn Sie eine eigene Lösung haben.

# %%
# Musterloesung
zahl_als_text = "50"\n,

# %% [markdown]
# #### Lösung zu Aufgabe 2:

# %%
# Ihre Loesung

# %% [markdown]
# ### Musterlösung
# Bitte erst öffnen, wenn Sie eine eigene Lösung haben.

# %%
# Musterloesung
summe = int(zahl_als_text) + 20\n,

# %% [markdown]
# ### Aufgabe 3: Float zu Integer (Nachkommastellen)\nErstelle eine Variable `pi_naeherung = 3.99`. \nWandle diese Variable in einen Integer um und gib das Ergebnis aus. Was fällt dir auf, was mit den Nachkommastellen passiert?

# %%
# Ihre Loesung

# %% [markdown]
# ### Musterlösung
# Bitte erst öffnen, wenn Sie eine eigene Lösung haben.

# %%
# Musterloesung
# Dein Code hier\n

# %% [markdown]
# #### Lösung zu Aufgabe 3:

# %% [markdown]
# ### Info
# Dieses Jupyter-Notebook wurde am 11.03.2026 um 08:17:30 mit dem Large-Language-Model gemini-3-flash-preview erzeugt.
# Der Prompt lautete: "Erzeuge ein Jupyter-Notebook im korrekten JSON-Format mit 5 einfache Python-Übungsaufgaben samt Lösungen zu Variablen. Dabei sollen insbesondere Typen und Typumwandlung geübt werden."
